# %% [markdown]
# ## Tree
#
# - A tree is a nonlinear data structure with hierarchical relationships between its elements
#
# without having any cycle, it is basically reversed from a real life tree.
#
# - It has Root node(Parent of the hierarchy) and sub categories
#
# - Each node has 2 components:
#     - Data
#     - Link to its sub category
#
#
# **Why a Tree?**
#
# - Quicker and Easier access to the data
# -Store hierarchical data, like folder structure, organization structure, XML/HTML data.
# - There are many different types of data structures which performs better in various situations
# - Binary Search Tree, AVL, Red Black Tree, Trie

# %%
# Basic tree

class TreeNode:
    def __init__(self, data, children = []):
        self.data = data
        # List of the children node
        self.children = children
    
    def __str__(self, level=0):
        ret = "   " * level + str(self.data) + "\n"
        for child in self.children:
            # Recursive call
            ret += child.__str__(level + 1)
        return ret
    
    def addChild(self, TreeNode):
        self.children.append(TreeNode)›


# Root
tree = TreeNode('Drinks', [])
# Nodes for root
cold = TreeNode('Cold', [])
hot = TreeNode('Hot', [])
# Sub nodes for cold
cola = TreeNode('Cola', [])
fanta = TreeNode('Fanta', [])
# Sub nodes for hot
tea = TreeNode('Tea', [])
coffee = TreeNode('Coffee', [])

# Add relationships to tree root
tree.addChild(cold)
tree.addChild(hot)
# Add relationships to subtees
# 1. cold subtree
cold.addChild(fanta)
cold.addChild(cola)
# 2 hot subtree
hot.addChild(coffee)
hot.addChild(tea)

print(tree)
# Out:
# Drinks
#    Cold
#       Fanta
#       Cola
#    Hot
#       Coffee
#       Tea
