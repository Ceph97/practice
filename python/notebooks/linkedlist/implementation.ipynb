# %%
class Node:
    def __init__(self, value):
        # Stores the actual value.
        self.value = value
        # Reference to next pointer
        # Set to None as we do not know the next neighbour.
        self.next = None

class LinkedList:
    def __init__(self):
        # Initially tail and head are the same node
        # new_node = Node(value)
        # self.head = new_node
        # self.tail = new_node
        # self.length = 1

        # Empty linked list
        self.head = None
        self.tail = None
        self.length = 0
    
    def __str__(self):
        temp_node = self.head
        result = ''
        while temp_node is not None:
            result += str(temp_node.value)
            if temp_node.next is not None:
                result += '->'
            temp_node = temp_node.next
        return result

    
    def append(self, value):
        new_node = Node(value)
        # If the linked list is empty.
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        # Add at the end of the linked list
        else:
            self.tail.next = new_node
            self.tail = new_node
        # append length
        self.length += 1

    
        


new_linked_list = LinkedList()
new_linked_list.append(10)
new_linked_list.append(20)
new_linked_list.append(50)
new_linked_list.append({"hello":1})

print(new_linked_list)
# Out:
# 10->20->50->{'hello': 1}

# %%
del str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del str
#
# NameError: name 'str' is not defined

# %%
duplicates = [1,2,3,2,3,44,5,5,6,6,6,6]
nonDupes = set()
for i in duplicates:
    nonDupes.add(i)
print(nonDupes)
# Out:
# {1, 2, 3, 5, 6, 44}

# %%
[1,2,3,4]
# Out:
# 4
