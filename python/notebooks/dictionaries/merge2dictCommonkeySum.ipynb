# %% [markdown]
# # Common Keys
#
# Define a function with takes two dictionaries as parameters and merge them and sum the values of common keys.
#
# Example:
#
# dict1 = ```{'a': 1, 'b': 2, 'c': 3}```
# dict2 = ```{'b': 3, 'c': 4, 'd': 5}```
# ```python
# merge_dicts(dict1, dict2)
# ```
# Output:
#
# ```{'a': 1, 'b': 5, 'c': 7, 'd': 5}```

# %%
from collections import defaultdict
def merge_dicts(dict1:defaultdict,dict2:defaultdict):
    # to avoid mutating the dict2 we need to make a copy of it:
    result = dict2.copy()

    for key,value in dict1.items():
        result[key] = result.get(key,0) + value
    return result

dict1 = {'a': 1, 'b': 2, 'c': 3, 'e': 1}
dict2 = {'b': 3, 'c': 4, 'd': 5}
merge_dicts(dict1,dict2)
# Out:
# {'b': 5, 'c': 7, 'd': 5, 'a': 1, 'e': 1}
